# %% [markdown]
# ### Autosplitter
#
# <i> This notebook splits image labels for us.

# %%
# Imports
from ultralytics.data.split import autosplit
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\kykis\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Splits the images based on the path.
autosplit(
    path=r"C:\Users\kykis\bunnycam\YOLO\datasets\model_1\images",
    weights=(0.9, 0.1, 0.0),             # (train, validation, test) fractional splits
    annotated_only=False,                # split only images with annotation file when True
)
# Out:
# Autosplitting images from C:\Users\kykis\bunnycam\YOLO\datasets\model_1\images
# : 100% ━━━━━━━━━━━━ 1044/1044 4.1Kit/s 0.3s.1s

# %% [markdown]
# <i>
# This will create autosplit_*.txt files. Then use txt-files in training like this:
# path: POINT TO THE Autosplit -folder
# train: autosplit_train.txt
# val: autosplit_val.txt
# test: autosplit_test.txt
