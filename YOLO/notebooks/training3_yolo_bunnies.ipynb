# %% [markdown]
# # Yolo Model Training 3
#
# | Item | Description|
# |---|---|
# |Model| `yolov11s`|
# |Dataset size| 1779 images|
# |Epochs| 30|
#
#
#
# #### Changes:
#
# * Added a validation split for training.
# * Added data augmentation into training.
# * Added ~350 more pictures into the dataset (Which includes pictures from a new home, so they should add quite a bit of context to the model.)

# %% [markdown]
# ---

# %% [markdown]
# ## Imports

# %%
from ultralytics import YOLO
import torch

# %% [markdown]
# ---
#
# ## Training

# %%
# Initialize our yolo model as 'model'
model = YOLO("yolo11s.pt")

# Trains the model using the yaml instructions.
# Data augmentation lines have been added to improve the model.
train = model.train(
    data=r"C:\Users\kykis\bunnycam\YOLO\datasets\model_3\dataset.yaml",   # path to the yaml file
    epochs=35,                                                            # Amount of batch cycles
    patience=5,                                                           # If it doesn't improve after 5 epochs, stop
    imgsz=640,                                                            # Image size
    workers=0,                                                            # Reduce this to lower ram usage amount.
    device=0,                                                             # Use GPU
    hsv_h=0.015,                                                          # hue shift
    hsv_s=0.7,                                                            # saturation
    hsv_v=0.4,                                                            # brightness
    fliplr=0.5,                                                           # horizontal flip probability
    degrees=10.0,                                                         # rotation
    scale=0.5,                                                            # zoom
    translate=0.1,                                                        # shift
    shear=2.0,
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.51 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.49  Python-3.13.13 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=C:\Users\kykis\bunnycam\YOLO\datasets\model_3\dataset.yaml, degrees=10.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=35, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train-12, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=5, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\kykis\bunnycam\runs\detect\train-12, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=2.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    820182  ultralytics.nn.modules.head.Detect           [2, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,428,566 parameters, 9,428,550 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.20.0 ms, read: 14.63.8 MB/s, size: 71.6 KB)
# train: Scanning C:\Users\kykis\bunnycam\YOLO\datasets\model_3\labels... 1402 images, 209 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1402/1402 592.0it/s 2.4s0.1s
# train: New cache created: C:\Users\kykis\bunnycam\YOLO\datasets\model_3\labels.cache
# val: Fast image access  (ping: 0.10.1 ms, read: 13.42.9 MB/s, size: 59.5 KB)
# val: Scanning C:\Users\kykis\bunnycam\YOLO\datasets\model_3\labels... 172 images, 24 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 172/172 407.9it/s 0.4s0.1s
# val: New cache created: C:\Users\kykis\bunnycam\YOLO\datasets\model_3\labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to C:\Users\kykis\bunnycam\runs\detect\train-12\labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\Users\kykis\bunnycam\runs\detect\train-12
# Starting training for 35 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/35      3.97G      1.258      3.019      1.218         13        640: 100% ━━━━━━━━━━━━ 88/88 2.0it/s 43.7s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.6it/s 3.8s0.5ss
#                    all        172        170      0.855      0.595      0.704      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/35      4.22G       1.25      1.317      1.222         15        640: 100% ━━━━━━━━━━━━ 88/88 2.5it/s 35.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.2it/s 1.9s0.4s
#                    all        172        170       0.61      0.191      0.244      0.121
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/35      4.22G      1.294      1.245      1.254         19        640: 100% ━━━━━━━━━━━━ 88/88 2.5it/s 34.9s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.2it/s 1.9s0.4s
#                    all        172        170      0.701      0.492      0.535      0.328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/35      4.22G      1.263      1.138      1.224         13        640: 100% ━━━━━━━━━━━━ 88/88 2.6it/s 34.2s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.4it/s 1.8s0.4s
#                    all        172        170      0.783      0.594       0.69      0.456
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/35      4.22G      1.221      1.037      1.202         18        640: 100% ━━━━━━━━━━━━ 88/88 2.3it/s 37.9s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.6it/s 2.3s0.5s
#                    all        172        170      0.811      0.762      0.833      0.459
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/35      4.22G      1.193     0.9862      1.185         10        640: 100% ━━━━━━━━━━━━ 88/88 1.8it/s 47.8s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.5it/s 2.4s0.5s
#                    all        172        170      0.756      0.747      0.801      0.497
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/35      4.22G      1.177     0.9395      1.178         19        640: 100% ━━━━━━━━━━━━ 88/88 1.8it/s 48.6s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.6it/s 2.3s0.5s
#                    all        172        170      0.856      0.817      0.903      0.571
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/35      4.22G      1.151      0.896      1.151         23        640: 100% ━━━━━━━━━━━━ 88/88 2.0it/s 44.0s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.2s0.5s
#                    all        172        170       0.86      0.872       0.89      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9
0.717
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/35      4.22G     0.7487     0.4572     0.9787         11        640: 100% ━━━━━━━━━━━━ 88/88 2.2it/s 39.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.4it/s 1.8s0.4s
#                    all        172        170      0.885      0.932      0.948      0.747
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/35      4.22G     0.7375     0.4274     0.9729          8        640: 100% ━━━━━━━━━━━━ 88/88 2.7it/s 32.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.6it/s 1.7s0.4s
#                    all        172        170      0.926      0.917      0.954      0.741
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/35      4.22G     0.7359     0.4297     0.9786          9        640: 100% ━━━━━━━━━━━━ 88/88 2.7it/s 32.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.6it/s 1.7s0.4s
#                    all        172        170      0.901       0.94      0.959      0.754
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/35      4.22G     0.7146      0.416     0.9699          9        640: 100% ━━━━━━━━━━━━ 88/88 2.7it/s 32.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.5it/s 1.7s0.4s
#                    all        172        170      0.926      0.915      0.951      0.758
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/35      4.22G     0.7044     0.4063     0.9565         10        640: 100% ━━━━━━━━━━━━ 88/88 2.6it/s 33.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.4it/s 1.7s0.4s
#                    all        172        170      0.896      0.943      0.952      0.755
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/35      4.22G     0.7001     0.4002     0.9588         11        640: 100% ━━━━━━━━━━━━ 88/88 2.5it/s 35.6s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.1it/s 1.9s0.4s
#                    all        172        170      0.928      0.925       0.95      0.757
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/35      4.22G     0.6777      0.384     0.9629         10        640: 100% ━━━━━━━━━━━━ 88/88 2.5it/s 35.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.1it/s 1.9s0.4s
#                    all        172        170      0.925      0.924      0.954      0.764
#
# 35 epochs completed in 0.421 hours.
# Optimizer stripped from C:\Users\kykis\bunnycam\runs\detect\train-12\weights\last.pt, 19.2MB
# Optimizer stripped from C:\Users\kykis\bunnycam\runs\detect\train-12\weights\best.pt, 19.2MB
#
# Validating C:\Users\kykis\bunnycam\runs\detect\train-12\weights\best.pt...
# Ultralytics 8.4.49  Python-3.13.13 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
# YOLO11s summary (fused): 101 layers, 9,413,574 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.5it/s 2.4s0.5s
#                    all        172        170      0.925      0.924      0.954      0.764
#                   Aune         95         95      0.905      0.926      0.943      0.745
#                  Dippi         75         75      0.945      0.923      0.964      0.783
# Speed: 0.1ms preprocess, 3.6ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to C:\Users\kykis\bunnycam\runs\detect\train-12

# %% [markdown]
# ---
#
# ## Predictions / Testing

# %% [markdown]
# ### Manual Validation

# %% [markdown]
# #### Picture 2

# %%
model = YOLO(r"C:\Users\kykis\bunnycam\runs\detect\train-12\weights\best.pt")
results = model.predict(
    source=r"C:\Users\kykis\bunnycam\YOLO\datasets\validation_2\device_E8F60A870078_date_13-05-26_hours_01.54.53.jpg",
    conf=0.25,
    device=0
)

results[0].show()
# Out:
# image 1/1 C:\Users\kykis\bunnycam\YOLO\datasets\validation_2\device_E8F60A870078_date_13-05-26_hours_01.54.53.jpg: 480x640 1 Aune, 7.9ms
# Speed: 1.5ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# ### Picture 3

# %%
model = YOLO(r"C:\Users\kykis\bunnycam\runs\detect\train-12\weights\best.pt")
results = model.predict(
    source=r"C:\Users\kykis\bunnycam\YOLO\datasets\validation_2\device_E8F60A870078_date_13-05-26_hours_18.09.09.jpg",
    conf=0.25,
    device=0
)

results[0].show()
# Out:
# image 1/1 C:\Users\kykis\bunnycam\YOLO\datasets\validation_2\device_E8F60A870078_date_13-05-26_hours_18.09.09.jpg: 480x640 (no detections), 8.2ms
# Speed: 1.6ms preprocess, 8.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# #### Picture 4

# %%
model = YOLO(r"C:\Users\kykis\bunnycam\runs\detect\train-12\weights\best.pt")
results = model.predict(
    source=r"C:\Users\kykis\bunnycam\YOLO\datasets\validation_2\device_E8F60A870078_date_13-05-26_hours_21.26.11.jpg",
    conf=0.25,
    device=0
)

results[0].show()
# Out:
# image 1/1 C:\Users\kykis\bunnycam\YOLO\datasets\validation_2\device_E8F60A870078_date_13-05-26_hours_21.26.11.jpg: 480x640 2 Aunes, 1 Dippi, 8.7ms
# Speed: 1.6ms preprocess, 8.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
